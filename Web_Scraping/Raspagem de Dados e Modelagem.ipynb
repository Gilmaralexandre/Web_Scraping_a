# %% [markdown]
# # Raspagem de dados e Modelagem de dados
#
# - Nesta página vou realizar a extração de dados da página do IBGE, e posteriormente modelar esses dados em um dataframe do pandas.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
uf_url = f'https://www.ibge.gov.br/cidades-e-estados/sp.html' #site em questão
browsers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \(KHTML, like Gecko) Chrome / 86.0.4240.198Safari / 537.36"} #Mascara
page = requests.get(uf_url, headers = browsers) #Resquisição
    
soup = BeautifulSoup(page.content, 'html.parser') 
indicadores = soup.select('.indicador') #elemento html

# %%
indicadores #busca de todos os dados
# Out:
# [<div class="indicador"><div class="ind-label"><p>Governador</p></div><p class="ind-value">RODRIGO GARCIA<small>   [2019]</small></p></div>,
#  <div class="indicador"><div class="ind-label"><p>Capital</p></div><p class="ind-value">São Paulo<small>   [2010]</small></p></div>,
#  <div class="indicador"><div class="ind-label"><p>Gentílico</p></div><p class="ind-value">paulista</p></div>,
#  <div class="indicador"><div class="ind-label"><img alt="Área Territorial" src="/modules/mod_quick_facts/css/images/area.png"><p>Área Territorial</p></img></div><p class="ind-value">248.219,485 <span class="indicador-unidade">km²</span><small>   [2021]</small></p></div>,
#  <div class="indicador"><div class="ind-label"><img alt="População estimada" src="/modules/mod_quick_facts/css/images/populacao.png"/><p>População estimada</p></div><p class="ind-value">46.649.132 <span class="indicador-unidade">pessoas</span><small>   [2021]</small></p></div>,
#  <div class="indicador"><input class="chart-values" type="hidden" value='["3.37","5.58","9.20","18.50","28.93","36.81","52.28","72.36","102.25","127.11","148.96","166.25"]'/><input class="chart-labels" type="hidden" value='["1872","1890","1900","1920","1940","1950","1960","1970","1980","1991","2000","2010"]'/><div class="ind-label"><img alt="Densidade demográfica" src="/modules/mod_quick_facts/css/images/densidade.png"/><p>Densidade demográfica</p></div><p class="ind-value">166,25 <span class="indicador-unidade">hab/km²</span><small>   [2010]</small></p></div>,
#  <div class="indicador"><input class="chart-values" type="hidden" value='["6075606","6100512","6025963","5926923","5805590","5673142","5537627","5365948","5343661","5276326","5367614","5409187","5414208","5396803"]'/><input class="chart-labels" type="hidden" value='["2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"]'/><div class="ind-label"><img alt="Matrículas no ensino fundamental" src="/modules/mod_quick_facts/css/images/escolarizacao.png"/><p>Matrículas no ensino fundamental</p></div><p class="ind-value">5.396.803 <span class="indicador-unidade">matrículas</span><small>   [2021]</small></p></div>,
#  <div class="indicador"><input class="chart-values" type="hidden" value='["0.578","0.702","0.783"]'/><input class="chart-labels" type="hidden" value='["1991","2000","2010"]'/><div class="ind-label"><img alt="IDH &lt;span&gt;Índice de desenvolvimento humano&lt;/span&gt;" src="/modules/mod_quick_facts/css/images/idh.png"/><p>IDH <span>Índice de desenvolvimento humano</span></p></div><p class="ind-value">0,783<small>   [2010]</small></p></div>,
#  <div class="indicador"><input class="chart-values" type="hidden" value='["196875515.66748","209486514.33074","218966501.13932","218622576.68826","232822496.56706"]'/><input class="chart-labels" type="hidden" value='["2013","2014","2015","2016","2017"]'/><div class="ind-label"><img alt="Receitas realizadas" src="/modules/mod_quick_facts/css/images/receitas.png"/><p>Receitas realizadas</p></div><p class="ind-value">232.822.496,57 <span class="indicador-unidade">R$ (×1000)</span><small>   [2017]</small></p></div>,
#  <div class="indicador"><input class="chart-values" type="hidden" value='["197870171.92207","209842014.024","220506971.96347","219266294.16031","231982243.69176"]'/><input class="chart-labels" type="hidden" value='["2013","2014","2015","2016","2017"]'/><div class="ind-label"><img alt="Despesas empenhadas" src="/modules/mod_quick_facts/css/images/despesas.png"/><p>Despesas empenhadas</p></div><p class="ind-value">231.982.243,69 <span class="indicador-unidade">R$ (×1000)</span><small>   [2017]</small></p></div>,
#  <div class="indicador"><input class="chart-values" type="hidden" value='["1197","1308","1432","1482","1723","1712","1898","1946","1814","1836"]'/><input class="chart-labels" type="hidden" value='["2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"]'/><div class="ind-label"><img alt="Rendimento mensal domiciliar per capita" src="/modules/mod_quick_facts/css/images/pib.png"/><p>Rendimento mensal domiciliar per capita</p></div><p class="ind-value">1.836 <span class="indicador-unidade">R$</span><small>   [2021]</small></p></div>,
#  <div class="indicador"><input class="chart-values" type="hidden" value='["15098096","16464703","17852829","19139118","20537980","21968359","23286890","24560202","25718248","26605042","27332101","28138698","29057749","30058975","30778960","31455473"]'/><input class="chart-labels" type="hidden" value='["2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"]'/><div class="ind-label"><img alt="Total de veículos" src="/modules/mod_quick_facts/css/images/veiculos.png"/><p>Total de veículos</p></div><p class="ind-value">31.455.473 <span class="indicador-unidade">veículos</span><small>   [2021]</small></p></div>]

# %%
# Estruturando os dados, a  fim de extrair os dados percebemos que necessitamos da class .indicador  e nas divs 'ind-label' e 'ind-value'

def scraping_uf(uf: str): 
    uf_url = f'https://www.ibge.gov.br/cidades-e-estados/{uf}.html'
    browsers = {'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 \(KHTML, like Gecko) Chrome / 86.0.4240.198Safari / 537.36"}
    page = requests.get(uf_url, headers = browsers)
    
    soup = BeautifulSoup(page.content, 'html.parser')
    indicadores = soup.select('.indicador')
    
    uf_dict = {
        dado.select('.ind-label')[0].text: dado.select('.ind-value')[0].text
        for dado in indicadores
    }
    
    return uf_dict

# %%
# Utilizaremos este conceito para localizar cada estado
dictionary = {
'Acre':	'AC',	
'Alagoas':	'AL',	
'Amapá':	'AP',
'Amazonas':	'AM',	
'Bahia':	'BA',	
'Ceará': 'CE',	
'Distrito Federal':	'DF',	
'Espírito Santo':	'ES',
'Goiás':	'GO',
'Maranhão':	'MA',	
'Mato Grosso':	'MT',	
'Mato Grosso do Sul':	'MS',
'Minas Gerais':	'MG',	
'Pará':	'PA',	
'Paraíba':	'PB',	
'Paraná':	'PR',	
'Pernambuco':	'PE',	
'Piauí':	'PI',	
'Rio de Janeiro':	'RJ',	
'Rio Grande do Norte':	'RN',	
'Rio Grande do Sul':	'RS',	
'Rondônia':	'RO',	
'Roraima':	'RR',	
'Santa Catarina':	'SC',	
'São Paulo':	'SP',	
'Sergipe':	'SE',	
'Tocantins':	'TO',	
}

# %%
lista = [x for x in dictionary.values()]

for i in range(len(lista)):
    lista[i] = lista[i].lower()
print(lista)

# Transformando a lista em palavras minusculas
# Out:
# ['ac', 'al', 'ap', 'am', 'ba', 'ce', 'df', 'es', 'go', 'ma', 'mt', 'ms', 'mg', 'pa', 'pb', 'pr', 'pe', 'pi', 'rj', 'rn', 'rs', 'ro', 'rr', 'sc', 'sp', 'se', 'to']

# %%
estados_ = []
for x in range(27):
  estado = scraping_uf(lista[x])
  estados_.append(estado)

# %%
estados_
# Out:
# [{'Governador': 'GLADSON DE LIMA CAMELI\xa0\xa0\xa0[2019]',
#   'Capital': 'Rio Branco\xa0\xa0\xa0[2010]',
#   'Gentílico': 'acriano',
#   'Área Territorial': '164.173,431 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '906.876 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '4,47 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '153.015 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,663\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '6.632.883,11 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '6.084.416,81 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '888 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '320.173 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'JOSE RENAN VASCONCELOS CALHEIROS FILHO\xa0\xa0\xa0[2019]',
#   'Capital': 'Maceió\xa0\xa0\xa0[2010]',
#   'Gentílico': 'alagoano',
#   'Área Territorial': '27.830,661 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '3.365.351 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '112,33 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '458.782 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,631\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '11.950.438,46 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '10.460.634,92 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '777 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '981.823 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'ANTONIO WALDEZ GÓES DA SILVA\xa0\xa0\xa0[2019]',
#   'Capital': 'Macapá\xa0\xa0\xa0[2010]',
#   'Gentílico': 'amapaense',
#   'Área Territorial': '142.470,762 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '877.613 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '4,69 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '133.839 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,708\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '5.396.417,14 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '4.224.464,09 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '855 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '224.208 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'WILSON MIRANDA LIMA\xa0\xa0\xa0[2019]',
#   'Capital': 'Manaus\xa0\xa0\xa0[2010]',
#   'Gentílico': 'amazonense',
#   'Área Territorial': '1.559.167,878 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '4.269.995 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '2,23 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '702.763 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,674\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '17.328.459,43 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '15.324.896,56 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '800 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '1.014.026 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'RUI COSTA DOS SANTOS\xa0\xa0\xa0[2019]',
#   'Capital': 'Salvador\xa0\xa0\xa0[2010]',
#   'Gentílico': 'baiano',
#   'Área Territorial': '564.760,429 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '14.985.284 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '24,82 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '1.946.957 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,660\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '50.191.003,24 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '45.570.160,00 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '843 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '4.695.972 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'CAMILO SOBREIRA DE SANTANA\xa0\xa0\xa0[2019]',
#   'Capital': 'Fortaleza\xa0\xa0\xa0[2010]',
#   'Gentílico': 'cearense',
#   'Área Territorial': '148.894,447 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '9.240.580 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '56,76 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '1.161.434 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,682\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '28.420.222,47 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '24.608.352,18 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '881 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '3.513.199 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'IBANEIS ROCHA BARROS JUNIOR\xa0\xa0\xa0[2019]',
#   'Capital': 'Brasília\xa0\xa0\xa0[2010]',
#   'Gentílico': 'brasiliense',
#   'Área Territorial': '5.760,784 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '3.094.325 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '444,07 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '369.128 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,824\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '23.812.211,27 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '21.990.464,68 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '2.513 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '1.979.698 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'JOSE RENATO CASAGRANDE\xa0\xa0\xa0[2019]',
#   'Capital': 'Vitória\xa0\xa0\xa0[2010]',
#   'Gentílico': 'capixaba ou espírito-santense',
#   'Área Territorial': '46.074,448 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '4.108.508 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '76,25 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '503.003 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,740\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '19.685.616,74 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '14.392.338,00 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.295 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '2.160.432 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'RONALDO RAMOS CAIADO\xa0\xa0\xa0[2019]',
#   'Capital': 'Goiânia\xa0\xa0\xa0[2010]',
#   'Gentílico': 'goiano',
#   'Área Territorial': '340.242,856 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '7.206.589 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '17,65 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '855.021 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,735\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '37.885.335,17 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '24.248.380,34 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.276 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '4.369.349 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'FLÁVIO DINO DE CASTRO E COSTA\xa0\xa0\xa0[2019]',
#   'Capital': 'São Luís\xa0\xa0\xa0[2010]',
#   'Gentílico': 'maranhense',
#   'Área Territorial': '329.651,496 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '7.153.262 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '19,81 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '1.112.636 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,639\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '18.503.261,35 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '17.627.170,76 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '635 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '1.940.475 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'MAURO MENDES FERREIRA\xa0\xa0\xa0[2019]',
#   'Capital': 'Cuiabá\xa0\xa0\xa0[2010]',
#   'Gentílico': 'mato-grossense',
#   'Área Territorial': '903.207,047 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '3.567.234 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '3,36 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '486.568 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,725\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '23.958.528,84 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '18.187.363,27 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.362 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '2.443.785 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'REINALDO AZAMBUJA SILVA\xa0\xa0\xa0[2019]',
#   'Capital': 'Campo Grande\xa0\xa0\xa0[2010]',
#   'Gentílico': 'sul-mato-grossense ou mato-grossense-do-sul',
#   'Área Territorial': '357.147,995 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '2.839.188 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '6,86 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '391.975 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,729\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '16.396.655,77 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '14.506.915,37 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.471 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '1.764.689 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'ROMEU ZEMA NETO\xa0\xa0\xa0[2019]',
#   'Capital': 'Belo Horizonte\xa0\xa0\xa0[2010]',
#   'Gentílico': 'mineiro',
#   'Área Territorial': '586.513,983 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '21.411.923 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '33,41 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '2.407.107 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,731\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '97.199.823,16 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '98.391.669,16 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.325 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '12.503.229 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'HELDER ZAHLUTH BARBALHO\xa0\xa0\xa0[2019]',
#   'Capital': 'Belém\xa0\xa0\xa0[2010]',
#   'Gentílico': 'paraense',
#   'Área Territorial': '1.245.870,700 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '8.777.124 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '6,07 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '1.389.983 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,646\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '25.849.446,10 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '22.533.470,05 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '847 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '2.352.727 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'JOÃO AZEVEDO LINS FILHO\xa0\xa0\xa0[2019]',
#   'Capital': 'João Pessoa\xa0\xa0\xa0[2010]',
#   'Gentílico': 'paraibano',
#   'Área Territorial': '56.467,242 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '4.059.905 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '66,70 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '540.919 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,658\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '13.097.005,32 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '10.074.700,04 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '876 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '1.470.901 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'CARLOS ROBERTO MASSA JUNIOR\xa0\xa0\xa0[2019]',
#   'Capital': 'Curitiba\xa0\xa0\xa0[2010]',
#   'Gentílico': 'paranaense',
#   'Área Territorial': '199.298,981 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '11.597.484 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '52,40 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '1.348.296 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,749\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '60.163.576,12 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '55.534.402,97 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.541 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '8.339.982 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'PAULO HENRIQUE SARAIVA CÂMARA\xa0\xa0\xa0[2019]',
#   'Capital': 'Recife\xa0\xa0\xa0[2010]',
#   'Gentílico': 'pernambucano',
#   'Área Territorial': '98.067,877 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '9.674.793 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '89,63 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '1.249.850 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,673\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '35.746.028,97 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '33.320.486,44 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '829 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '3.334.479 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'MARIA REGINA SOUSA\xa0\xa0\xa0[2019]',
#   'Capital': 'Teresina\xa0\xa0\xa0[2010]',
#   'Gentílico': 'piauiense',
#   'Área Territorial': '251.755,481 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '3.289.290 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '12,40 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '459.871 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,646\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '12.124.215,62 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '9.676.736,32 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '837 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '1.338.918 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'CLÁUDIO BOMFIM DE CASTRO E SILVA\xa0\xa0\xa0[2019]',
#   'Capital': 'Rio de Janeiro\xa0\xa0\xa0[2010]',
#   'Gentílico': 'fluminense',
#   'Área Territorial': '43.750,425 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '17.463.349 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '365,23 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '1.945.408 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,761\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '78.488.140,79 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '67.965.548,70 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.724 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '7.296.355 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'MARIA DE FATIMA BEZERRA\xa0\xa0\xa0[2019]',
#   'Capital': 'Natal\xa0\xa0\xa0[2010]',
#   'Gentílico': 'potiguar, norte-rio-grandense, rio-grandense-do-norte',
#   'Área Territorial': '52.809,599 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '3.560.903 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '59,99 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '447.692 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,684\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '13.527.552,73 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '11.330.957,55 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.109 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '1.444.307 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'RANOLFO VIEIRA JÚNIOR\xa0\xa0\xa0[2019]',
#   'Capital': 'Porto Alegre\xa0\xa0\xa0[2010]',
#   'Gentílico': 'gaúcho ou sul-rio-grandense',
#   'Área Territorial': '281.707,151 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '11.466.630 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '39,79 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '1.257.992 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,746\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '66.397.468,18 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '62.476.279,34 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.787 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '7.689.278 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'MARCOS JOSE ROCHA DOS SANTOS\xa0\xa0\xa0[2019]',
#   'Capital': 'Porto Velho\xa0\xa0\xa0[2010]',
#   'Gentílico': 'rondoniense ou rondoniano',
#   'Área Territorial': '237.765,347 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '1.815.278 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '6,58 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '244.815 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,690\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '9.122.310,72 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '7.085.530,02 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.023 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '1.113.279 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'ANTONIO OLIVERIO GARCIA DE ALMEIDA\xa0\xa0\xa0[2019]',
#   'Capital': 'Boa Vista\xa0\xa0\xa0[2010]',
#   'Gentílico': 'roraimense',
#   'Área Territorial': '223.644,530 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '652.713 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '2,01 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '103.123 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,707\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '4.266.318,55 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '3.865.094,27 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.046 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '250.675 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'CARLOS MOISÉS DA SILVA\xa0\xa0\xa0[2019]',
#   'Capital': 'Florianópolis\xa0\xa0\xa0[2010]',
#   'Gentílico': 'catarinense ou barriga-verde',
#   'Área Territorial': '95.730,690 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '7.338.473 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '65,29 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '900.240 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,774\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '34.696.772,82 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '25.595.103,38 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.718 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '5.786.199 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'RODRIGO GARCIA\xa0\xa0\xa0[2019]',
#   'Capital': 'São Paulo\xa0\xa0\xa0[2010]',
#   'Gentílico': 'paulista',
#   'Área Territorial': '248.219,485 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '46.649.132 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '166,25 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '5.396.803 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,783\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '232.822.496,57 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '231.982.243,69 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.836 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '31.455.473 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'BELIVALDO CHAGAS SILVA\xa0\xa0\xa0[2019]',
#   'Capital': 'Aracaju\xa0\xa0\xa0[2010]',
#   'Gentílico': 'sergipano ou sergipense',
#   'Área Territorial': '21.938,188 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '2.338.474 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '94,35 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '320.638 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,665\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '10.145.046,95 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '8.494.927,20 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '929 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '871.776 veículos\xa0\xa0\xa0[2021]'},
#  {'Governador': 'WANDERLEI BARBOSA CASTRO\xa0\xa0\xa0[2019]',
#   'Capital': 'Palmas\xa0\xa0\xa0[2010]',
#   'Gentílico': 'tocantinense',
#   'Área Territorial': '277.423,627 km²\xa0\xa0\xa0[2021]',
#   'População estimada': '1.607.363 pessoas\xa0\xa0\xa0[2021]',
#   'Densidade demográfica': '4,98 hab/km²\xa0\xa0\xa0[2010]',
#   'Matrículas no ensino fundamental': '227.743 matrículas\xa0\xa0\xa0[2021]',
#   'IDH Índice de desenvolvimento humano': '0,699\xa0\xa0\xa0[2010]',
#   'Receitas realizadas': '10.305.099,01 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Despesas empenhadas': '8.929.456,44 R$ (×1000)\xa0\xa0\xa0[2017]',
#   'Rendimento mensal domiciliar per capita': '1.028 R$\xa0\xa0\xa0[2021]',
#   'Total de veículos': '791.463 veículos\xa0\xa0\xa0[2021]'}]

# %%
for x in estados_:
  for y in range(27):
    estado = estados_[y]

    for indicador in estado:
      if ']' in estado[indicador]:
        estado[indicador] = estado[indicador].split(']')[0][:-8]
      else:
        estado[indicador] = estado[indicador]

print(estados_)
# Out:
# [{'Governador': 'GLADSON DE LIMA CAMELI', 'Capital': 'Rio Branco', 'Gentílico': 'acriano', 'Área Territorial': '164.173,431 km²', 'População estimada': '906.876 pessoas', 'Densidade demográfica': '4,47 hab/km²', 'Matrículas no ensino fundamental': '153.015 matrículas', 'IDH Índice de desenvolvimento humano': '0,663', 'Receitas realizadas': '6.632.883,11 R$ (×1000)', 'Despesas empenhadas': '6.084.416,81 R$ (×1000)', 'Rendimento mensal domiciliar per capita': '888 R$', 'Total de veículos': '320.173 veículos'}, {'Governador': 'JOSE RENAN VASCONCELOS CALHEIROS FILHO', 'Capital': 'Maceió', 'Gentílico': 'alagoano', 'Área Territorial': '27.830,661 km²', 'População estimada': '3.365.351 pessoas', 'Densidade demográfica': '112,33 hab/km²', 'Matrículas no ensino fundamental': '458.782 matrículas', 'IDH Índice de desenvolvimento humano': '0,631', 'Receitas realizadas': '11.950.438,46 R$ (×1000)', 'Despesas empenhadas': '10.460.634,92 R$ (×1000)', 'Rendimento mensal domiciliar per capita': '777 R$', 'Total de veículos': '981.823 veículos'}, {'Governador': 'ANTONIO WALDEZ GÓES DA SILVA', 'Capital': 'Macapá', 'Gentílico': 'amapaense', 'Área Territorial': '142.470,762 km²', 'População estimada': '877.613 pessoas', 'Densidade demográfica': '4,69 hab/km²', 'Matrículas no ensino fundamental': '133.839 matrículas', 'IDH Índice de desenvolvimento humano': '0,708', 'Receitas realizadas': '5.396.417,14 R$ (×1000)', 'Despesas empenhadas': '4.224.464,09 R$ (×1000)', 'Rendimento mensal domiciliar per capita': '855 R$', 'Total de veículos': '224.208 veículos'}, {'Governador': 'WILSON MIRANDA LIMA', 'Capital': 'Manaus', 'Gentílico': 'amazonense', 'Área Territorial': '1.559.167,878 km²', 'População estimada': '4.269.995 pessoas', 'Densidade demográfica': '2,23 hab/km²', 'Matrículas no ensino fundamental': '702.763 matrículas', 'IDH Índice de desenvolvimento humano': '0,674', 'Receitas realizadas': '17.328.459,43 R$ (×1000)', 'Despesas empenhadas': '15.324.896,56 R$ (×1000)', 'Rendimento mensal domiciliar per capita': '800 R$', 'Total de veículos': '1.014.026 veículos'}, {'Governador': 'RUI COSTA DOS SANTOS', 'Capital': 'Salvador', 'Gentílico': 'baiano', 'Área Territorial': '564.760,429 km²', 'População estimada': '14.985.284 pessoas', 'Densidade demográfica': '24,82 hab/km²', 'Matrículas no ensino fundamental': '1.946.957 matrículas', 'IDH Índice de desenvolvimento humano': '0,660', 'Receitas realizadas': '50.191.003,24 R$ (×1000)', 'Despesas empenhadas': '45.570.160,00 R$ (×1000)', 'Rendimento mensal domiciliar per capita': '843 R$', 'Total de veículos': '4.695.972 veículos'}, {'Governador': 'CAMILO SOBREIRA DE SANTANA', 'Capital': 'Fortaleza', 'Gentílico': 'cearense', 'Área Territorial': '148.894,447 km²', 'População estimada': '9.240.580 pessoas', 'Densidade demográfica': '56,76 hab/km²', 'Matrículas no ensino fundamental': '1.161.434 matrículas', 'IDH Índice de desenvolvimento humano': '0,682', 'Receitas realizadas': '28.420.222,47 R$ (×1000)', 'Despesas empenhadas': '24.608.352,18 R$ (×1000)', 'Rendimento mensal domiciliar per capita': '881 R$', 'Total de veículos': '3.513.199 veículos'}, {'Governador': 'IBANEIS ROCHA BARROS JUNIOR', 'Capital': 'Brasília', 'Gentílico': 'brasiliense', 'Área Territorial': '5.760,784 km²', 'População estimada': '3.094.325 pessoas', 'Densidade demográfica': '444,07 hab/km²', 'Matrículas no ensino fundamental': '369.128 matrículas', 'IDH Índice de desenvolvimento humano': '0,824', 'Receitas realizadas': '23.812.211,27 R$ (×1000)', 'Despesas empenhadas': '21.990.464,68 R$ (×1000)', 'Rendimento mensal domiciliar per capita': '2.513 R$', 'Total de veículos': '1.979.698 veículos'}, {'Governador': 'JOSE RENATO CASAGRANDE', 'Capital': 'Vitória', 'Gentílico': 'capixaba ou espírito-santense', 'Área Territorial': '46.074,448 km²', 'População estimada': '4.108.508 pessoas', 'Densidade demográfica': '76,25 hab/km²', 'Matrículas no ensino fundamental': '503.003 matrículas', 'IDH Índice de desenvolvimento humano': '0, ...

# %%
keys = []
values = []

for x in estados_:
  values.append(x.values())

for x in estado:
  keys.append(x)

# %%
df = pd.DataFrame(values, columns = keys)
df
# Out:
#                                 Governador         Capital  \
# 0                   GLADSON DE LIMA CAMELI      Rio Branco
# 1   JOSE RENAN VASCONCELOS CALHEIROS FILHO          Maceió
# 2             ANTONIO WALDEZ GÓES DA SILVA          Macapá
# 3                      WILSON MIRANDA LIMA          Manaus
# 4                     RUI COSTA DOS SANTOS        Salvador
# 5               CAMILO SOBREIRA DE SANTANA       Fortaleza
# 6              IBANEIS ROCHA BARROS JUNIOR        Brasília
# 7                   JOSE RENATO CASAGRANDE         Vitória
# 8                     RONALDO RAMOS CAIADO         Goiânia
# 9            FLÁVIO DINO DE CASTRO E COSTA        São Luís
# 10                   MAURO MENDES FERREIRA          Cuiabá
# 11                 REINALDO AZAMBUJA SILVA    Campo Grande
# 12                         ROMEU ZEMA NETO  Belo Horizonte
# 13                 HELDER ZAHLUTH BARBALHO           Belém
# 14                 JOÃO AZEVEDO LINS FILHO     João Pessoa
# 15             CARLOS ROBERTO MASSA JUNIOR        Curitiba
# 16           PAULO HENRIQUE SARAIVA CÂMARA          Recife
# 17                      MARIA REGINA SOUSA        Teresina
# 18        CLÁUDIO BOMFIM DE CASTRO E SILVA  Rio de Janeiro
# 19                 MARIA DE FATIMA BEZERRA           Natal
# 20                   RANOLFO VIEIRA JÚNIOR    Porto Alegre
# 21            MARCOS JOSE ROCHA DOS SANTOS     Porto Velho
# 22      ANTONIO OLIVERIO GARCIA DE ALMEIDA       Boa Vista
# 23                  CARLOS MOISÉS DA SILVA   Florianópolis
# 24                          RODRIGO GARCIA       São Paulo
# 25                  BELIVALDO CHAGAS SILVA         Aracaju
# 26                WANDERLEI BARBOSA CASTRO          Palmas
#
#                                             Gentílico   Área Territorial  \
# 0                                             acriano    164.173,431 km²
# 1                                            alagoano     27.830,661 km²
# 2                                           amapaense    142.470,762 km²
# 3                                          amazonense  1.559.167,878 km²
# 4                                              baiano    564.760,429 km²
# 5                                            cearense    148.894,447 km²
# 6                                         brasiliense      5.760,784 km²
# 7                       capixaba ou espírito-santense     46.074,448 km²
# 8                                              goiano    340.242,856 km²
# 9                                          maranhense    329.651,496 km²
# 10                                     mato-grossense    903.207,047 km²
# 11        sul-mato-grossense ou mato-grossense-do-sul    357.147,995 km²
# 12                                            mineiro    586.513,983 km²
# 13                                           paraense  1.245.870,700 km²
# 14                                          paraibano     56.467,242 km²
# 15                                         paranaense    199.298,981 km²
# 16                                       pernambucano     98.067,877 km²
# 17                                          piauiense    251.755,481 km²
# 18                                         fluminense     43.750,425 km²
# 19  potiguar, norte-rio-grandense, rio-grandense-d...     52.809,599 km²
# 20                        gaúcho ou sul-rio-grandense    281.707,151 km²
# 21                          rondoniense ou rondoniano    237.765,347 km²
# 22                                         roraimense    223.644,530 km²
# 23                       catarinense ou barriga-verde     95.730,690 km²
# 24                                           paulista    248.219,485 km²
# 25                            sergipano ou sergipense     21.938,188 km²
# 26                                       tocantinense    277.423,627 km²
#
#     População estimada Densidade demográfica  \
# 0      906.876 pessoas          4,47 hab/km²
# 1    3.365.351 pessoas        112,33 hab/km²
# 2      877.613 pessoas          4,69 hab/km²
# 3    4.269.995 pessoas          2,23 hab/km²
# 4   14.985.284 pessoas         24,82 hab/km²
# 5    9.240.580 pessoas         56,76 hab/km²
# 6    3.094.325 pessoas        444,07 hab/km²
# 7    4.108.508 pessoas         76,25 hab/km²
# 8    7.206.589 pessoas         17,65 hab/km²
# 9    7.153.262 pessoas         19,81 hab/km²
# 10   3.567.234 pessoas          3,36 hab/km²
# 11   2.839.188 pessoas          6,86 hab/km²
# 12  21.411.923 pessoas         33,41 hab/km²
# 13   8.777.124 pessoas          6,07 hab/km²
# 14   4.059.905 pessoas         66,70 hab/km²
# 15  11.597.484 pessoas         52,40 hab/km²
# 16   9.674.793 pessoas         89,63 hab/km²
# 17   3.289.290 pessoas         12,40 hab/km²
# 18  17.463.349 pessoas        365,23 hab/km²
# 19   3.560.903 pessoas         59,99 hab/km²
# 20  11.466.630 pessoas         39,79 hab/km²
# 21   1.815.278 pessoas          6,58 hab/km²
# 22     652.713 pessoas          2,01 hab/km²
# 23   7.338.473 pessoas         65,29 hab/km²
# 24  46.649.132 pessoas        166,25 hab/km²
# 25   2.338.474 pessoas         94,35 hab/km²
# 26   1.607.363 pessoas          4,98 hab/km²
#
#    Matrículas no ensino fundamental IDH Índice de desenvolvimento humano  \
# 0                 153.015 matrículas                                 0,663
# 1                 458.782 matrículas                                 0,631
# 2                 133.839 matrículas                                 0,708
# 3                 702.763 matrículas                                 0,674
# 4               1.946.957 matrículas                                 0,660
# 5               1.161.434 matrículas                                 0,682
# 6                 369.128 matrículas                                 0,824
# 7                 503.003 matrículas                                 0,740
# 8                 855.021 matrículas                                 0,735
# 9               1.112.636 matrículas                                 0,639
# 10                486.568 matrículas                                 0,725
# 11                391.975 matrículas                                 0,729
# 12              2.407.107 matrículas                                 0,731
# 13              1.389.983 matrículas                                 0,646
# 14                540.919 matrículas                                 0,658
# 15              1.348.296 matrículas                                 0,749
# 16              1.249.850 matrículas                                 0,673
# 17                459.871 matrículas                                 0,646
# 18              1.945.408 matrículas                                 0,761
# 19                447.692 matrículas                                 0,684
# 20              1.257.992 matrículas                                 0,746
# 21                244.815 matrículas                                 0,690
# 22                103.123 matrículas                                 0,707
# 23                900.240 matrículas                                 0,774
# 24              5.396.803 matrículas                                 0,783
# 25                320.638 matrículas                                 0,665
# 26                227.743 matrículas                                 0,699
#
#           Receitas realizadas        Despesas empenhadas  \
# 0     6.632.883,11 R$ (×1000)    6.084.416,81 R$ (×1000)
# 1    11.950.438,46 R$ (×1000)   10.460.634,92 R$ (×1000)
# 2     5.396.417,14 R$ (×1000)    4.224.464,09 R$ (×1000)
# 3    17.328.459,43 R$ (×1000)   15.324.896,56 R$ (×1000)
# 4    50.191.003,24 R$ (×1000)   45.570.160,00 R$ (×1000)
# 5    28.420.222,47 R$ (×1000)   24.608.352,18 R$ (×1000)
# 6    23.812.211,27 R$ (×1000)   21.990.464,68 R$ (×1000)
# 7    19.685.616,74 R$ (×1000)   14.392.338,00 R$ (×1000)
# 8    37.885.335,17 R$ (×1000)   24.248.380,34 R$ (×1000)
# 9    18.503.261,35 R$ (×1000)   17.627.170,76 R$ (×1000)
# 10   23.958.528,84 R$ (×1000)   18.187.363,27 R$ (×1000)
# 11   16.396.655,77 R$ (×1000)   14.506.915,37 R$ (×1000)
# 12   97.199.823,16 R$ (×1000)   98.391.669,16 R$ (×1000)
# 13   25.849.446,10 R$ (×1000)   22.533.470,05 R$ (×1000)
# 14   13.097.005,32 R$ (×1000)   10.074.700,04 R$ (×1000)
# 15   60.163.576,12 R$ (×1000)   55.534.402,97 R$ (×1000)
# 16   35.746.028,97 R$ (×1000)   33.320.486,44 R$ (×1000)
# 17   12.124.215,62 R$ (×1000)    9.676.736,32 R$ (×1000)
# 18   78.488.140,79 R$ (×1000)   67.965.548,70 R$ (×1000)
# 19   13.527.552,73 R$ (×1000)   11.330.957,55 R$ (×1000)
# 20   66.397.468,18 R$ (×1000)   62.476.279,34 R$ (×1000)
# 21    9.122.310,72 R$ (×1000)    7.085.530,02 R$ (×1000)
# 22    4.266.318,55 R$ (×1000)    3.865.094,27 R$ (×1000)
# 23   34.696.772,82 R$ (×1000)   25.595.103,38 R$ (×1000)
# 24  232.822.496,57 R$ (×1000)  231.982.243,69 R$ (×1000)
# 25   10.145.046,95 R$ (×1000)    8.494.927,20 R$ (×1000)
# 26   10.305.099,01 R$ (×1000)    8.929.456,44 R$ (×1000)
#
#    Rendimento mensal domiciliar per capita    Total de veículos
# 0                                   888 R$     320.173 veículos
# 1                                   777 R$     981.823 veículos
# 2                                   855 R$     224.208 veículos
# 3                                   800 R$   1.014.026 veículos
# 4                                   843 R$   4.695.972 veículos
# 5                                   881 R$   3.513.199 veículos
# 6                                 2.513 R$   1.979.698 veículos
# 7                                 1.295 R$   2.160.432 veículos
# 8                                 1.276 R$   4.369.349 veículos
# 9                                   635 R$   1.940.475 veículos
# 10                                1.362 R$   2.443.785 veículos
# 11                                1.471 R$   1.764.689 veículos
# 12                                1.325 R$  12.503.229 veículos
# 13                                  847 R$   2.352.727 veículos
# 14                                  876 R$   1.470.901 veículos
# 15                                1.541 R$   8.339.982 veículos
# 16                                  829 R$   3.334.479 veículos
# 17                                  837 R$   1.338.918 veículos
# 18                                1.724 R$   7.296.355 veículos
# 19                                1.109 R$   1.444.307 veículos
# 20                                1.787 R$   7.689.278 veículos
# 21                                1.023 R$   1.113.279 veículos
# 22                                1.046 R$     250.675 veículos
# 23                                1.718 R$   5.786.199 veículos
# 24                                1.836 R$  31.455.473 veículos
# 25                                  929 R$     871.776 veículos
# 26                                1.028 R$     791.463 veículos

# %% [markdown]
# # Termino este parte  com o df construído, posteriormente vou classificar um objetivo teórico(modelagem descritiva, ou modelagem estatitica e tenter realizar uma análise de dados ou a predição de algum valor mediante a base de dados)
